# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
income=pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
income
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
income.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=income.index, y=income.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
sns.lineplot(data=income)
# Out:
# <AxesSubplot:>

# %%
plt.plot(income.index, income.income)

# %%
df=pd.read_csv("C:/Users/Admin/Downloads/dataset_209770_6.txt",sep=' ')

# %%
sns.lmplot(x='x', y='y',data=df)

# %%
df2=pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv')

# %%
df3=df2.set_index('Unnamed: 0')

# %%
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
g=sns.heatmap(df3,cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df3
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
df4=pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
df4
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
df5=df4.assign(num_roles=df4.roles.str.count(',')+1)

# %%
df5
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
df6=df5[['id','num_roles']]

# %%
df6=df6.set_index('id')

# %%
df6.hist()
# Out:
# array([[<AxesSubplot:title={'center':'num_roles'}>]], dtype=object)

# %%
df6.hist()
# Out:
# array([[<AxesSubplot:title={'center':'num_roles'}>]], dtype=object)

# %%
df_iris=pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv')

# %%
df_iris
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
df2=df_iris.rename(columns={'Unnamed: 0':'indexx'})

# %%
df2=df2.set_index('indexx')

# %% [markdown]
# ##

# %%
sns.kdeplot(x=df2['sepal length'], data=df2)
sns.distplot(a=df2['sepal length'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal length', ylabel='Density'>

# %%
df2=df2.rename(columns={'sepal length':'sepal_length','sepal width':'sepal_width','petal length':'petal_length','petal width':'petal_width'})
df2
# Out:
#         sepal_length  sepal_width  petal_length  petal_width
# indexx
# 0                5.1          3.5           1.4          0.2
# 1                4.9          3.0           1.4          0.2
# 2                4.7          3.2           1.3          0.2
# 3                4.6          3.1           1.5          0.2
# 4                5.0          3.6           1.4          0.2
# ...              ...          ...           ...          ...
# 145              6.7          3.0           5.2          2.3
# 146              6.3          2.5           5.0          1.9
# 147              6.5          3.0           5.2          2.0
# 148              6.2          3.4           5.4          2.3
# 149              5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
for i in df2:
    sns.kdeplot(data=df2,legend=True)
    #sns.distplot(a=df2[i])

# %%
petal_len_data=df2['petal_length']

# %%
sns.violinplot(data=petal_len_data)
# Out:
# <AxesSubplot:>

# %%
petal_len_data.hist()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df2)
